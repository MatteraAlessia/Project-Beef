# %%
import pandas as pd
import numpy as np

# %%
df2 = pd.read_excel(r"C:\Users\eymem\Documents\GitHub\Project-Data-Wrangling-and-Retrieval\EU beef and veal balance sheet meat imports.xlsx")

# %%
df2.head()
# Out:
#                         Metric  Calendar Year     2000      2001      2002   \
# 0  Gross Indigenous Production            NaN  7907.022  7738.413  7892.621
# 1                 Live Imports            NaN     0.333     0.153     0.635
# 2                 Live Exports            NaN   126.676    77.207   108.399
# 3               Net Production            NaN  7780.680  7661.358  7784.857
# 4                 Meat Imports            NaN   203.590   185.340   275.869
#
#       2003      2004      2005      2006      2007   ...     2016      2017   \
# 0  7685.488  7705.792  7445.106  7395.655  7427.718  ...  7163.843  7192.635
# 1     1.354     1.299     1.298     2.886     3.596  ...     1.617     1.818
# 2   103.755   101.985    70.828    54.671    54.944  ...   228.250   246.314
# 3  7583.088  7605.107  7375.577  7343.870  7376.370  ...  6937.210  6948.140
# 4   290.762   360.839   428.863   474.763   396.377  ...   350.590   347.702
#
# ...

# %%
df3 = pd.read_csv(r"C:\Users\eymem\Documents\GitHub\Project-Data-Wrangling-and-Retrieval\Beef Prices.csv")

# %%
df3.head()
# Out:
#   Member State Code Member State Name Week - Begin Date Week - End Date  \
# 0                AT           Austria        06/08/2007      12/08/2007
# 1                AT           Austria        13/08/2007      19/08/2007
# 2                AT           Austria        19/12/2016      25/12/2016
# 3                AT           Austria        19/12/2016      25/12/2016
# 4                AT           Austria        06/08/2007      12/08/2007
#
#    Week Number                     Category   Unit  Price
# 0           32  Adult male indicative price  100kg  281.7
# 1           33  Adult male indicative price  100kg  283.9
# 2           51  Adult male indicative price  100kg  382.3
# 3           51                  Young bulls  100kg  396.7
# 4           32                        Bulls  100kg  273.4
